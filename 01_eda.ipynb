# %% [markdown]
# <a href="https://colab.research.google.com/github/tanuiivy/AI-Coursework-2025/blob/main/01_eda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from getpass import getpass
username = input("GitHub username: ")
token = getpass("GitHub personal access token: ")
# !git clone https://{username}:{token}@github.com/{username}/nse-guidance-system.git
# %cd nse-guidance-system
# Out:
# GitHub username: tanuiivy
# GitHub personal access token: ··········
# Cloning into 'nse-guidance-system'...
# remote: Enumerating objects: 15, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 15 (delta 0), reused 12 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (15/15), done.
# /content/nse-guidance-system

# %%
# !pwd
import torch
print(torch.cuda.is_available())
# Out:
# /content/nse-guidance-system
# True

# %%
# !pip install kagglehub[pandas-datasets]
import kagglehub

# %%
path = kagglehub.dataset_download("macmini62/nairobi-securities-exchangense-stocks-data")
print("Downloaded to:", path)
# Out:
# ...
# 100%|██████████| 4.02M/4.02M [00:00<00:00, 56.5MB/s]
# Extracting files...
# Downloaded to: /root/.cache/kagglehub/datasets/macmini62/nairobi-securities-exchangense-stocks-data/versions/2

# %%
import os
for f in os.listdir(path):
    print(f)
# Out:
# NSE_data_all_stocks_2017.csv
# NSE_data_all_stocks_2010.csv
# NSE_data_all_stocks_2013.csv
# NSE_data_all_stocks_2008.csv
# NSE_data_all_stocks_2020.csv
# NSE_data_all_stocks_2018.csv
# NSE_data_all_stocks_2016.csv
# NSE_data_all_stocks_2023.csv
# NSE_data_all_stocks_2011.csv
# NSE_data_all_stocks_2022.csv
# NSE_data_all_stocks_2007.csv
# NSE_data_all_stocks_2015.csv
# NSE_data_all_stocks_2012.csv
# NSE_data_all_stocks_2014.csv
# NSE_data_all_stocks_2009.csv
# NSE_data_all_stocks_2021.csv
# NSE_data_all_stocks_2019.csv
# NSE_data_all_stocks_2025.csv
# NSE_data_all_stocks_2024.csv

# %%
# !mkdir -p ml/data/raw
# !cp -r {path}/* ml/data/raw/
# !ls ml/data/raw
# Out:
# NSE_data_all_stocks_2007.csv  NSE_data_all_stocks_2017.csv
# NSE_data_all_stocks_2008.csv  NSE_data_all_stocks_2018.csv
# NSE_data_all_stocks_2009.csv  NSE_data_all_stocks_2019.csv
# NSE_data_all_stocks_2010.csv  NSE_data_all_stocks_2020.csv
# NSE_data_all_stocks_2011.csv  NSE_data_all_stocks_2021.csv
# NSE_data_all_stocks_2012.csv  NSE_data_all_stocks_2022.csv
# NSE_data_all_stocks_2013.csv  NSE_data_all_stocks_2023.csv
# NSE_data_all_stocks_2014.csv  NSE_data_all_stocks_2024.csv
# NSE_data_all_stocks_2015.csv  NSE_data_all_stocks_2025.csv
# NSE_data_all_stocks_2016.csv

# %%
import pandas as pd
df = pd.read_csv("ml/data/raw/NSE_data_all_stocks_2025.csv")
print("First 5 records:")
df.head()
# Out:
# First 5 records:
#        Date  Code                     Name  12m Low  12m High  Day Low  \
# 0  2-Jan-25  EGAD              Eaagads Ltd     10.8     24.10     12.0
# 1  2-Jan-25  KUKZ               Kakuzi Plc    365.0    440.00    385.0
# 2  2-Jan-25  KAPC  Kapchorua Tea Kenya Plc    198.0    424.25    236.0
# 3  2-Jan-25  LIMT           Limuru Tea Plc    295.0    423.50    350.0
# 4  2-Jan-25  SASN               Sasini Plc     13.3     20.40     14.8
#
#    Day High  Day Price Previous Change Change% Volume Adjusted Price
# 0      12.0      12.00       12      -       -      -              -
# 1     400.0     392.50      385    7.5   1.95%    200              -
# 2     240.0     239.25      235   4.25   1.81%   1000              -
# 3     350.0     350.00      350      -       -      -              -
# 4      15.0      15.00       15      -       -  38700              -

# %%
df_check = pd.read_csv("ml/data/raw/NSE_data_all_stocks_2025.csv")

codes = df_check['Code'].unique()
print("Total unique codes in 2025 file:", len(codes))

code_name_pairs = df_check[['Code', 'Name']].drop_duplicates().sort_values('Code')
print(code_name_pairs.to_string(index=False))
# Out:
# Total unique codes in 2025 file: 75
#    Code                                     Name
#    ABSA                      ABSA Bank Kenya Plc
#    AMAC                 Africa Mega Agricorp Plc
#     ARM                           ARM Cement Plc
#    BAMB                       Bamburi Cement Ltd
#     BAT       British American Tobacco Kenya Plc
#     BKG                             BK Group Plc
#     BOC                            BOC Kenya Plc
#    BRIT                      Britam Holdings Plc
#    CABL                  East African Cables Plc
#    CARB                 Carbacid Investments Plc
#    CGEN                  Car and General (K) Ltd
#     CIC                  CIC Insurance Group Ltd
#    COOP           Co-operative Bank of Kenya Ltd
#    CRWN                   Crown Paints Kenya Plc
#    CTUM            Centum Investment Company Plc
#    DCON                Deacons (East Africa) Plc
#     DTK             Diamond Trust Bank Kenya Ltd
# ...

# %%
df_check = pd.read_csv("ml/data/raw/NSE_data_all_stocks_2023.csv")

codes = df_check['Code'].unique()
print("Total unique codes in 2025 file:", len(codes))

code_name_pairs = df_check[['Code', 'Name']].drop_duplicates().sort_values('Code')
print(code_name_pairs.to_string(index=False))
# Out:
# Total unique codes in 2025 file: 72
#    Code                                     Name
#    ABSA                      ABSA Bank Kenya Plc
#     ARM                           ARM Cement Plc
#    BAMB                       Bamburi Cement Ltd
#     BAT       British American Tobacco Kenya Plc
#     BKG                             BK Group Plc
#     BOC                            BOC Kenya Plc
#    BRIT                      Britam Holdings Plc
#    CABL                  East African Cables Plc
#    CARB                 Carbacid Investments Plc
#    CGEN                  Car and General (K) Ltd
#     CIC                  CIC Insurance Group Ltd
#    COOP           Co-operative Bank of Kenya Ltd
#    CRWN                   Crown Paints Kenya Plc
#    CTUM            Centum Investment Company Plc
#    DCON                Deacons (East Africa) Plc
#     DTK             Diamond Trust Bank Kenya Ltd
#    EABL               East African Breweries Ltd
# ...
